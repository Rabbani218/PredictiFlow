# %% [markdown]
# # Time Series Analysis and Forecasting with PredictiFlow
#
# This notebook demonstrates the initial data exploration and analysis capabilities of PredictiFlow platform. We'll analyze sample time series data and implement core functionalities for time series analysis.
#
# ## Objectives:
# 1. Load and validate time series data
# 2. Perform data preprocessing and quality checks
# 3. Analyze time series components (trend, seasonality, residuals)
# 4. Test for stationarity
# 5. Visualize key insights
#
# Let's start by importing required libraries.

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
import warnings
warnings.filterwarnings('ignore')

# Set random seed for reproducibility
np.random.seed(42)
